# %% [markdown]
# <a href="https://colab.research.google.com/github/JuJu78/transcription_youtube/blob/main/Transcription_vid%C3%A9o_YouTube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube_transcript_api
from IPython.display import clear_output
import re
from google.colab import files
clear_output()

# %% [markdown]
# ##Entrez à la ligne 1 de la cellule ci-dessous l'URL de la vidéo YouTube pour laquelle vous souhaitez obtenir la transcription

# %%
URL = 'https://www.youtube.com/watch?v=iUQklO_h4cY'
regex = r'(?:https?:\/\/)?(?:[0-9A-Z-]+\.)?(?:youtube|youtu|youtube-nocookie)\.(?:com|be)\/(?:watch\?v=|watch\?.+&v=|embed\/|v\/|.+\?v=)?([^&=\n%\?]{11})'
ID_YOUTUBE_1 = re.findall(regex, URL, re.MULTILINE | re.IGNORECASE)
ID_YOUTUBE = ID_YOUTUBE_1[0]
from youtube_transcript_api import YouTubeTranscriptApi
# retrieve the available transcripts

transcript_list = YouTubeTranscriptApi.list_transcripts(ID_YOUTUBE)
# iterate over all available transcripts
for transcript in transcript_list:

    # the Transcript object provides metadata properties
       print(
          transcript.video_id,
          transcript.language,
          transcript.language_code,
        # whether it has been manually created or generated by YouTube
          transcript.is_generated,
        # whether this transcript can be translated or not
          transcript.is_translatable,
        # a list of languages the transcript can be translated to
          transcript.translation_languages,
       )
    # fetch the actual transcript data
transcript.fetch
# Out:
# iUQklO_h4cY French (auto-generated) fr True True [{'language': 'Afrikaans', 'language_code': 'af'}, {'language': 'Albanian', 'language_code': 'sq'}, {'language': 'Amharic', 'language_code': 'am'}, {'language': 'Arabic', 'language_code': 'ar'}, {'language': 'Armenian', 'language_code': 'hy'}, {'language': 'Azerbaijani', 'language_code': 'az'}, {'language': 'Bangla', 'language_code': 'bn'}, {'language': 'Basque', 'language_code': 'eu'}, {'language': 'Belarusian', 'language_code': 'be'}, {'language': 'Bosnian', 'language_code': 'bs'}, {'language': 'Bulgarian', 'language_code': 'bg'}, {'language': 'Burmese', 'language_code': 'my'}, {'language': 'Catalan', 'language_code': 'ca'}, {'language': 'Cebuano', 'language_code': 'ceb'}, {'language': 'Chinese (Simplified)', 'language_code': 'zh-Hans'}, {'language': 'Chinese (Traditional)', 'language_code': 'zh-Hant'}, {'language': 'Corsican', 'language_code': 'co'}, {'language': 'Croatian', 'language_code': 'hr'}, {'language': 'Czech', 'language_co
# ...

# %%
french = transcript.translate('fr').fetch()
from operator import itemgetter, attrgetter
french_tri = sorted(french, key=itemgetter('start'))
for x in french_tri:
  print(x['text'])
# Out:
# [Musique]
# bonjour tout le monde
# alors première question arsène quand
# est-ce que tu as décidé de devenir
# joueur puis entraîneur ben on connaît
# souvent l'intensité de ses désirs et pas
# forcément les causes donc je savais
# toujours que ma vie allait être dans le
# foot parce pour moi ne pas être dans le
# foot c'était la mort ça paraît un peu
# cru mais j'ai été élevé dans un village
# où il y avait deux pôles la religion et
# football donc fait du football ta
# religion pays j'ai fait du football ma
# religion
# au départ j'ai essayé de combiner les
# deux parce que j'étais dans un village
# qui ne gagnaient pas souvent donc je me
# suis dit j'ai au match de foot avec le
# missel et j'ai lu la messe pendant les
# matches ça ne nous a pas beaucoup pdg
# que j'ai compris bien plus tard que ce
# qui faisait les miracles c'était les
# bons joueurs et les entraîneurs et des
# bons entraîneurs ils peuvent accompagner
# quel est justement le lien entre un bon
# ...

# %% [markdown]
# ##Exportez la transcription de la vidéo dans un fichier txt

# %%
with open("youtube_transcription.txt", "wt") as text_file:
  for x in french_tri:
    text_file.writelines(x['text'] + '\n')

files.download('youtube_transcription.txt')
